# %% [markdown]
# # General

# %% [markdown]
# ## Tag Cleaning

# %%
html_tag_cleaner = re.compile("<.*?>")

# %% [markdown]
# # Forza

# %% [markdown]
# ## Skip Startswith List

# %%
forza_skip_startswith_list = [
    "{{CarListInfobox",
    "{{CarListsNav"
]

# %%
list_sections_list = [
    "Traffic", 
    "Autovista-Only Cars"
]

# %% [markdown]
# ## Manufacturers Translation Dictionary

# %%
forza_manufacturer_translation_dict = {
    "AMG TD": "AMG Transport Dynamics",
    "Bently": "Bentley",
    "BMW Motorsport": "BMW",
    "Mercedes": "Mercedes-Benz",
    "MercedesAMG": "Mercedes-AMG",
    "MercedesBenz": "Mercedes-Benz",
    "Citroen": "Citroën",
    "FIAT": "Fiat",
    "Mclaren": "McLaren",
    "RAM": "Ram",
    "RollsRoyce": "Rolls-Royce",
    "Spania": "Spania GTA",
    "WMotors": "W Motors",
    "Cassie Currie": "Casey Currie",
    "Funco": "Funco Motorsports",
    "SRT": "Dodge",
    "Viper": "Dodge",
    "MINI": "Mini"
}

# %% [markdown]
# ## Manufacturers of Unobtainable Vehicles Dictionary

# %%
forza_unobtainable_vehicle_manufacturers_dict = {
    "Traffic": [
        "Audi", "Alfa Romeo", "Abarth", "Austin",
        "BMW",
        "Chevrolet", "Chrysler", 
        "Dodge", 
        "Ford", "Fiat",
        "GMC", 
        "Jeep",
        "Kenworth", "Kia",
        "Land Rover",
        "Mercedes-Benz", "Mazda", "Mini", "Mitsubishi",
        "Nissan", 
        "Playground", 
        "Subaru",
        "Toyota", 
        "Volkswagen", "Volvo"
    ],
    "Autovista-Only Cars": [
        "AMG Transport Dynamics", "Bentley"
    ],
    "Unobtainable Forza Horizon 5": [
        "Hot Wheels", "Playground"
    ]
}

# %% [markdown]
# ## How to Obtain Dictionary

# %%
forza_default_how_to_obtain_dict = {
    "Forza Motorsport 2": "Base Game",
    "Forza Motorsport 3": "Base Game",
    "Forza Motorsport 4": "Base Game",
    "Forza Motorsport 5": "Base Game",
    "Forza Motorsport 6": "Base Game",
    "Forza Motorsport 7": "Buy Cars",
    "Forza Horizon 1": "Autoshow",
    "Forza Horizon 2": "Autoshow",
    "Forza Horizon 3": "Autoshow",
    "Forza Horizon 4": "Autoshow",
    "Forza Horizon 5": "Autoshow",
}

# %%
fh2_how_to_obtain_skip_list = ["", "x360", "X360", "x1", "X1"]

# %%
forza_how_to_obtain_dict = {
    "Forza Motorsport 2": {
        "+": "Base Game",
        "L": "Limited Edition",
        "PO": "Pre-Order Car",
        "P": "2007 Peugeot #8 Peugeot Sport 908",
        "N": "Nissan Tournament Pack",
        "M": "March Car Pack",
        "S": "September Car Pack",
        "D": "December Car Pack",
        "U": "Unicorn"
    },
    "Forza Motorsport 3": {
        "Hy": "Hyundai Car Pack",
        "Ho": "Hot Holidays Car Pack",
        "A": "AutoWeek Car Show Pack",
        "V": "VIP Car Pack",
        "M": "Motorsport Legends Car Pack",
        "J": "Jalopnik Car Pack",
        "R": "Road & Track Car Pack",
        "E": "Exotic Car Pack",
        "S": "Summer Velocity Car Pack",
        "W": "World Class Car Pack",
        "C": "Community Choice Classics Car Pack",
        "U": "Ultimate Collection"
    },
    "Forza Motorsport 4": {
        "N": "November Speed Pack",
        "D": "December IGN Pack",
        "Ja": "January Jalopnik Pack",
        "F": "February ALMS (American Le Mans) Pack",
        "Mr": "March Pirelli Car Pack",
        "Ap": "April Alpinestars Pack",
        "My": "May Top Gear Car Pack",
        "Jn": "June Meguiar's Car Pack",
        "Jl": "July Car Pack",
        "Au": "August Playseat Car Pack",
        "S": "September Pennzoil Car Pack",
        "Po": "Porsche Pack",
        "Pr": "Pre-Order DLC",
        "V": "VIP Launch Bonus Cars Pack and VIP Membership Car Pack"
    },
    "Forza Motorsport 5": {
        "P": "Promotional Vehicles",
        "D": "Day One Car Pack",
        "L": "Limited Edition Car Pack",
        "V": "VIP Car Pack",
        "F": "LaFerrari Car Pack",
        "J": "January IGN Car Pack",
        "S": "The Smoking Tire Car Pack",
        "H": "Honda Legends Pack",
        "R": "Road America Booster Pack",
        "A": "Alpinestars Car Pack",
        "T": "Top Gear Car Pack",
        "LB": "Long Beach Booster Car Pack",
        "M": "Meguiar's Car Pack",
        "B": "Bondurant Car Pack",
        "N": "Nürburgring Car Pack",
        "W": "Hot Wheels Car Pack"
    },
    "Forza Motorsport 6": {
        "+": "Base Game",
        "U": "Unicorn",
        "F": "Free DLC",
        "A": "Ten Year Anniversary Car Pack",
        "V": "VIP Car Pack",
        "FF": "Fast and Furious™ Car Pack",
        "L": "Logitech G Car Pack",
        "E": "eBay Motors Car Pack",
        "M1": "Mobil 1 Car Pack",
        "P": "Polo Red Car Pack",
        "Alp": "Alpinestars Car Pack",
        "Por": "Porsche Expansion",
        "Me": "Meguiar's Car Pack",
        "TG": "Top Gear Car Pack",
        "F4": "Fallout 4 Promotional Car",
        "HW": "Hot Wheels Car Pack",
        "NA": "NASCAR Expansion",
        "10S": "Turn 10 Select Car Pack",
        "SU": "Turn 10 Summer Car Pack"
    },
    "Forza Motorsport 7": {
        "champ": "Championship",
        "vip": "Buy Cars, VIP Car Pack",
        "hoonigan": "Buy Cars, Hoonigan Car Pack",
        "tfotf": "Buy Cars, The Fate of the Furious Car Pack",
        "samsung": "Buy Cars, Samsung QLED Car Pack",
        "doritos": "Buy Cars, Doritos Car Pack",
        "hyundai": "Buy Cars, Hyundai Car Pack",
        "totinos": "Buy Cars, Totino's Car Pack",
        "dell": "Buy Cars, Dell Gaming Car Pack",
        "march": "Buy Cars, March Car Pack",
        "k1": "Buy Cars, K1 Speed Car Pack",
        "topgear": "Buy Cars, Top Gear Car Pack",
        "fd": "Buy Cars, Formula Drift Car Pack",
        "hot": "Buy Cars, Hot Wheels Car Pack",
        "bj": "Buy Cars, Barrett-Jackson Car Pack",
        "showcase": "Showcase",
        "update": "Buy Cars, Update",
        "leagues": "Leagues",
    },
    "Forza Horizon 1": {
        "A": "Autoshow, April Top Gear Car Pack", 
        "B": "Barn Find",
        "C": "Autoshow, 1000 Club Expansion Pack",
        "D": "Autoshow, December IGN Car Pack", 
        "F": "Autoshow, February Jalopnik Car Pack", 
        "H": "Autoshow, Honda Challenge Car Pack", 
        "J": "Autoshow, January Recaro Car Pack", 
        "M": "Autoshow, March Meguiar's Car Pack", 
        "N": "Autoshow, November Bondurant Car Pack", 
        "O": "Autoshow, October Car Pack", 
        "P": "Autoshow, Pre-Order Car Pack",
        "R": "Autoshow, Rally Expansion Pack",
        "U": "Unicorn", 
        "V": "Autoshow, VIP Launch Day Car Pack"
    },
    "Forza Horizon 2": {
        "D1": "Autoshow, Day One Car Pack",
        "F": "Autoshow, Falken Tire Car Pack",
        "F7": "Autoshow, Furious 7 Car Pack",
        "G": "Autoshow, G-Shock Car Pack",
        "I": "Autoshow, IGN Car Pack",
        "L": "Autoshow, Launch Bonus Car Pack", 
        "M": "Autoshow, Mobil 1 Car Pack",
        "MX5": "Autoshow, Mazda MX-5 Car Pack",
        "N": "Autoshow, NAPA Auto Parts Car Pack",
        "P": "Autoshow, Porsche Expansion",
        "PB": "Autoshow, Porsche Bonus Car Pack",
        "PGS": "Autoshow, Playground Select Car Pack",
        "Pre": "Autoshow, Pre-Order Car Pack",
        "R": "Autoshow, Rockstar Car Pack",
        "T": "Autoshow, Top Gear Car Pack",
        "V": "Autoshow, VIP Car Pack",
        "a": "Autoshow, Alpinestars Car Pack",
        "b": "Barn Find",
        "d": "Autoshow, Duracell Car Pack",
        "s": "Autoshow, Storm Island Expansion",
        "sb": "Barn Find, Storm Island Expansion",
    },
    "Forza Horizon 3": {
        "allstarsfh3": "Autoshow, All-Stars Car Pack",
        "alpinestarsfh3": "Autoshow, Alpinestars Car Pack",
        "barn": "Barn Find",
        "blizzard": "Autoshow, Blizzard Mountain Expansion",
        "duracellfh3": "Autoshow, Duracell Car Pack",
        "forza": "Forzathon",
        "forzab": "Forzathon, Barn Find",
        "gift": "Gifted",
        "hooniganfh3": "Autoshow, Hoonigan Car Pack",
        "hwe": "Autoshow, Hot Wheels Expansion",
        "hweb": "Barn Find, Hot Wheels Expansion",
        "logitechgfh3": "Autoshow, Logitech G Car Pack",
        "mountaindew": "Autoshow, Mountain Dew Car Pack",
        "playseatfh3": "Autoshow, Playseat Car Pack",
        "porschefh3": "Autoshow, Porsche Car Pack",
        "rockstarfh3": "Autoshow, Rockstar Energy Car Pack",
        "smokingtirefh3": "Autoshow, The Smoking Tire Car Pack",
        "vipfh3": "Autoshow, VIP",
        "wheel": "Wheelspin",
        "wheelspin": "Wheelspin"
    },
    "Forza Horizon 4": {
        "autoshow": "Autoshow",
        "barn": "Barn Find",
        "bond": "Autoshow, Best of Bond Car Pack",
        "car pass": "Autoshow, Car Pass",
        "event": "Event",
        "formula": "Autoshow, Formula Drift Car Pack",
        "fortune": "Fortune Island Expansion",
        "htf": "Hard to Find",
        "hw": "Autoshow, Hot Wheels Legends Car Pack",
        "jackson": "Autoshow, Barrett-Jackson Car Pack",
        "lego": "LEGO Speed Champions Expansion",
        "life": "Horizon Life",
        "mitsubishi": "Autoshow, Mitsubishi Motors Car Pack",
        "po": "Gifted, Pre-Order",
        "purchase": "House Purchase",
        "spin": "Wheelspin",
        "star": "Star Card",
        "tree": "Skill Tree",
        "un": "Unreleased, Exclusive Gift",
        "vip": "Gifted, VIP",
        "welcome pack": "Autoshow, Welcome Pack"
    },
    "Forza Horizon 5": {
        "un": "Unobtainable",
        "aa": "Autoshow, Accolade",
        "ac": "Accolade",
        "accolade": "Accolade",
        "ap": "Autoshow, Gifted, Promotional",
        "as": "Autoshow, Showcase",
        "auto": "Autoshow",
        "awh": "Autoshow, Wheelspin",
        "awha": "Autoshow, Wheelspin, Accolade",
        "barn": "Barn Find",
        "cc": "Car Collector",
        "cm": "Car Mastery",
        "ctrl": "Gifted, Forza Horizon 5 Limited Edition Xbox Controller",
        "fd": "Autoshow, Formula Drift Pack",
        "hs": "Horizon Story",
        "htf": "Hard to Find",
        "hwa": "Autoshow, Hot Wheels Expansion",
        "hww": "Wheelspin, Hot Wheels Expansion",
        "mb": "Midnight Battle",
        "pass": "Autoshow, Car Pass",
        "promo": "Gifted, Promotional",
        "ra": "Autoshow, Rally Adventure Expansion",
        "raa": "Autoshow, Apex Predators, Rally Adventure Expansion",
        "rag": "Autoshow, Grit Reapers, Rally Adventure Expansion",
        "rah": "Autoshow, Horizon Raptors, Rally Adventure Expansion",
        "vip": "Gifted, VIP",
        "wh": "Wheelspin",
        "wha": "Wheelspin, Accolade",
        "whmb": "Wheelspin, Midnight Battle",
        "wp": "Autoshow, Welcome Pack",
        "hr": "Autoshow, Horizon Racing Car Pack",
        "ita": "Autoshow, Italian Exotics Car Pack",
    },
}

# %% [markdown]
# ## Rarity Dictionary

# %%
forza_rarity_dict = {
    "c": "Common",
    "common": "Common", 
    "r": "Rare",
    "rare": "Rare",
    "e": "Epic", 
    "epic": "Epic", 
    "l": "Legendary", 
    "legendary": "Legendary", 
    "fe": "Forza Edition",
    "forza": "Forza Edition",
    "forza edition": "Forza Edition",
    "ae": "Anniversary Edition",
    "anniversary": "Anniversary Edition",
    "anniversary edition": "Anniversary Edition",
    "de": "Donut Edition", 
    "donut": "Donut Edition", 
    "donut edition": "Donut Edition", 
    "unreleased": "Unreleased",
    "Forza Motorsport 7 Tier 1": "Common",
    "Forza Motorsport 7 Tier 2": "Uncommon",
    "Forza Motorsport 7 Tier 3": "Rare",
    "Forza Motorsport 7 Tier 4": "Super Rare",
    "Forza Motorsport 7 Tier 5": "Legendary"
}

# %% [markdown]
# ## Performance Index Class Functions

# %%
fm1_racing_class_list = [
    "GT", "GTS", "P1"
]

# %%
def forza_pi_class_from_string(game, pi_string): 
    if game in ["Forza Motorsport 1"]: 
        if pi_string in fm1_racing_class_list: 
            return f"R-{pi_string}"
def forza_pi_class_from_number(game, pi_number): 
    if game in ["Forza Motorsport 2"]:
        if 0 <= pi_number <= 400:
            return "D"
        if 401 <= pi_number <= 550:
            return "C"
        if 551 <= pi_number <= 700:
            return "B"
        if 701 <= pi_number <= 850:
            return "A"
        if 851 <= pi_number <= 998:
            return "S"
        if pi_number == 999:
            return "U"
    if game in ["Forza Motorsport 3", "Forza Motorsport 4", "Forza Horizon 1"]: 
        if game in ["Forza Motorsport 3", "Forza Motorsport 4"]:
            if 100 <= pi_number <= 200:
                return "F"
            if 201 <= pi_number <= 275:
                return "E"
            if 276 <= pi_number <= 350:
                return "D"
            if 351 <= pi_number <= 425:
                return "C"
            if 426 <= pi_number <= 500:
                return "B"
        if game in ["Forza Horizon 1"]:
            if 100 <= pi_number <= 200:
                return "E"
            if 201 <= pi_number <= 300:
                return "D"
            if 301 <= pi_number <= 400:
                return "C"
            if 401 <= pi_number <= 500:
                return "B"
        if game in ["Forza Motorsport 3", "Forza Motorsport 4", "Forza Horizon 1"]:
            if 501 <= pi_number <= 600:
                return "A"
            if 601 <= pi_number <= 700:
                return "S"
            if 701 <= pi_number <= 800:
                return "R3"
        if game in ["Forza Motorsport 3", "Forza Horizon 1"]:
            if 801 <= pi_number <= 900:
                return "R2"
            if 901 <= pi_number <= 999:
                return "R1"
        if game in ["Forza Motorsport 3"]:
            if pi_number == 1000:
                return "X"
        if game in ["Forza Motorsport 4"]:
            if 801 <= pi_number <= 875:
                return "R2"
            if 876 <= pi_number <= 998:
                return "R1"
            if pi_number == 999:
                return "X"
    if game in ["Forza Motorsport 5", "Forza Motorsport 6", "Forza Motorsport 7"]: 
        if game in ["Forza Motorsport 5"]:
            if 100 <= pi_number <= 400:
                return "D"
        if game in ["Forza Motorsport 6", "Forza Motorsport 7"]:
            if 100 <= pi_number <= 300:
                return "E"
            if 301 <= pi_number <= 400:
                return "D"
        if game in ["Forza Motorsport 5", "Forza Motorsport 6", "Forza Motorsport 7"]:
            if 401 <= pi_number <= 500:
                return "C"
            if 501 <= pi_number <= 600:
                return "B"
            if 601 <= pi_number <= 700:
                return "A"
            if 701 <= pi_number <= 800:
                return "S"
            if 801 <= pi_number <= 900:
                return "R"
            if 901 <= pi_number <= 998:
                return "P"
            if pi_number == 999:
                return "X"
    if game in ["Forza Horizon 2", "Forza Horizon 3", "Forza Horizon 4", "Forza Horizon 5"]: 
        if 100 <= pi_number <= 500:
            return "D"
        if 501 <= pi_number <= 600:
            return "C"
        if 601 <= pi_number <= 700:
            return "B"
        if 701 <= pi_number <= 800:
            return "A"
        if 801 <= pi_number <= 900:
            return "S1"
        if 901 <= pi_number <= 998:
            return "S2"
        if pi_number == 999:
            return "X"

# %% [markdown]
# ## Country Dictionary

# %%
forza_country_dict = {
    "aus": "Austria",
    "can": "Canada",
    "ch": "China",
    "cro": "Croatia",
    "den": "Denmark",
    "fra": "France",
    "ger": "Germany",
    "ita": "Italy",
    "jpn": "Japan",
    "kor": "South Korea",
    "mex": "Mexico",
    "net": "Netherlands",
    "oz": "Australia",
    "spn": "Spain",
    "swe": "Sweden",
    "uk": "United Kingdom",
    "usa": "United States"
}

# %% [markdown]
# ## Type Dictionary

# %%
forza_type_dict = {
    "Forza Motorsport 7": {
        "1020": "Ultima 1020 Spec",
        "ariel": "Ariel Nomad Spec",
        "csm": "Classic Street Muscle",
        "efr": "Elite Factory Racers",
        "egt": "Exotic GT",
        "epr": "Early Prototype Racers",
        "esl": "Early Sport Luxury",
        "est": "Early Sport Touring",
        "f70s": "Formula 70's",
        "f90s": "Formula 90's",
        "fd": "Formula Drift",
        "fe": "Formula E",
        "fgpr": "Forza GP Racing",
        "fgr": "Forza Group Rally",
        "fgt": "Forza GT",
        "fnf": "The Fast and the Furious",
        "ford": "Formula Ford Spec",
        "fp1": "Forza P1",
        "fp2": "Forza P2",
        "fs": "Forza Specials",
        "ftc": "Forza Touring Cars",
        "ftt": "Forza Trophy Trucks",
        "gtrr": "GT Racing Reborn",
        "h": "Hypercars",
        "hhg": "Hot Hatch Genesis",
        "hhi": "Hot Hatch Icons",
        "hoonigan": "Hoonigan Racing Division",
        "hrrac": "Historic Road Racing",
        "hrrev": "Hot Road Revival",
        "i": "IndyCar",
        "mazda": "Formula Mazda Spec",
        "mercedes": "Mercedes-Benz Racing Truck Spec",
        "mhh": "Modern Hot Hatch",
        "mm": "Major Micros",
        "mor": "Modern Off Roaders",
        "msuv": "Modern SUV",
        "mx5": "Mazda MX-5 Cup Spec",
        "n": "NASCAR",
        "ndr": "Nostalgic Drag Racers",
        "orb": "Off-Road Buggies",
        "owl": "Open Wheel Legends",
        "pgr": "Prototype Group Racing",
        "polaris": "Polaris RZR Spec",
        "rh": "Rally Heroes",
        "rom": "Rebirth Of Muscle",
        "rots": "Rise of the Supercar",
        "rxc": "Radical RXC Spec",
        "scha": "Supercars Championship",
        "sci": "Sport Compact Icons",
        "scom": "Sport Compact",
        "scou": "Sport Coupe",
        "sgt": "Sport GT",
        "sgti": "Sport GT Icons",
        "sl": "Sport Luxury",
        "sr8": "Radical SR8 Spec",
        "sral": "Showroom Rally",
        "sren": "Supercar Renaissance",
        "st": "Sport Touring",
        "sti": "Sport Touring Icons",
        "tbogp": "The Birth Of Grand Prix",
        "tt": "Track Toys",
        "vgtr": "Vintage GT Racing",
        "vor": "Vintage Off-Roaders",
        "vscom": "Vintage Sport Compact",
        "vscou": "Vintage Sport Coupe",
        "vsgt": "Vintage Sport GT",
    },
    "Forza Horizon 3": {
        "asiansportscars": "Asian Sports Cars",
        "buggies": "Buggies",
        "classicmuscle": "Classic Muscle",
        "classicracers": "Classic Racers",
        "classicrally": "Classic Rally",
        "cult": "Cult Classics",
        "cultclassics": "Cult Classics",
        "euro": "European Sports Cars",
        "europeansportscars": "European Sports Cars",
        "extremeoffroad": "Extreme Offroad",
        "extremetracktoys": "Extreme Track Toys",
        "gt": "GT Cars",
        "gtcars": "GT Cars",
        "hothatch": "Hot Hatch",
        "hypercars": "Hypercars",
        "modernmuscle": "Modern Muscle",
        "modernrally": "Modern Rally",
        "modernsupercars": "Modern Supercars",
        "offroad": "Offroad",
        "rallymonsters": "Rally Monsters",
        "rareclassics": "Rare Classics",
        "retroh": "Retro Hot Hatch",
        "retrohothatch": "Retro Hot Hatch",
        "retromuscle": "Retro Muscle",
        "retrorally": "Retro Rally",
        "retrosaloons": "Retro Saloons",
        "retrosupercars": "Retro Supercars",
        "rodsandcustoms": "Rods and Customs",
        "sportsutilityheroes": "Sports Utility Heroes",
        "supergt": "Super GT",
        "superhothatch": "Super Hot Hatch",
        "supers": "Super Saloons",
        "supersaloons": "Super Saloons",
        "vansandutility": "Vans and Utility",
    }
}
